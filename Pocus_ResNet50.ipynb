# %% [markdown]
# <a href="https://colab.research.google.com/github/BruunoRangel/Planejamento-Ultrassom-/blob/main/Pocus_ResNet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function, division
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
from torchsummary import summary
import time
import os
import copy
from sklearn.metrics import confusion_matrix
from torchvision.models import resnet50
from torchvision.models import resnet50
plt.ion()   # interactive mode
from PIL import Image
import random
# connect drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls 'gdrive/MyDrive/Modelo_01/data/data_pocus/'
# Out:
# test  train  val

# %%
# dataset com shape das imagens variados 
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((170,170)),
       
        transforms.ToTensor(),
    ]),
    'val': transforms.Compose([
        transforms.Resize((170,170)),
    
        transforms.ToTensor()
    ]),
    'test': transforms.Compose([
        transforms.Resize((170,170)),
       
        transforms.ToTensor(),
    ]),
}

data_dir = 'gdrive/MyDrive/Modelo_01/data/data_pocus/'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val', 'test']}

#Loading the datasets
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=24, shuffle=True, num_workers=2) for x in ['train', 'val', 'test']}

dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val', 'test']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
path = 'gdrive/MyDrive/Modelo_01/data/data_pocus/train/'

subdirs = os.listdir(path)

fig, axs = plt.subplots(1, 3, figsize=(15, 10))
for i, subdir in enumerate(subdirs):
    subdir_path = os.path.join(path, subdir)
    imgs = os.listdir(subdir_path)
    img_path = os.path.join(subdir_path, random.choice(imgs))
    img = plt.imread(img_path)
    axs[i].imshow(img)
    axs[i].set_title(f" {subdir}")
    axs[i].axis("off")
plt.show()

# %%
#Tamanhos darasets 
print("Quantidade de imagens dataset de treino:",len(image_datasets['train']))
print("Quantidade de imagens dataset de validação:",len(image_datasets['val']))
print("Quantidade de imagens dataset de teste:",len(image_datasets['val']))
# Out:
# Quantidade de imagens dataset de treino: 1371
# Quantidade de imagens dataset de validação: 469
# Quantidade de imagens dataset de teste: 469

# %%
#Quantidades de batchs em cada dataloader 
print("Quantidade de Batchs dataloader de treino:",len(dataloaders['train']))
print("Quantidade de Batchs dataloader de validação:",len(dataloaders['val']))
print("Quantidade de Batchs dataloader de teste:",len(dataloaders['test']))
# Out:
# Quantidade de Batchs dataloader de treino: 58
# Quantidade de Batchs dataloader de validação: 20
# Quantidade de Batchs dataloader de teste: 15

# %%
# Conferindo os 2° batchs de treino se estão com suas dimensãoes corretas [n°de imagens, canal de cada imagem, linhas das imagens, colunas das imagens  ]
# Correto: [24,3,170,170]
c = 0 
for i in dataloaders['train']:
  print(i[0].shape)
  if c == 1:
    break
  c +=1
# Out:
# torch.Size([24, 3, 170, 170])
# torch.Size([24, 3, 170, 170])

# %%
# Check which GPU we are using
# !nvidia-smi
# Out:
# Thu May  4 14:12:14 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8     9W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
inputs, classes = next(iter(dataloaders['train']))

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


print('Batch of training data')
inputs, classes = next(iter(dataloaders['train']))
# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])
print('min = ', np.min(inputs.numpy()))
print('median = ', np.median(inputs.numpy()))
print('mean = ', np.mean(inputs.numpy()))
print('max = ', np.max(inputs.numpy()))


print('Batch of validation data')
inputs, classes = next(iter(dataloaders['val']))
# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])
print('min = ', np.min(inputs.numpy()))
print('median = ', np.median(inputs.numpy()))
print('mean = ', np.mean(inputs.numpy()))
print('max = ', np.max(inputs.numpy()))

print('Batch of test data')
inputs, classes = next(iter(dataloaders['test']))
# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])
print('min = ', np.min(inputs.numpy()))
print('median = ', np.median(inputs.numpy()))
print('mean = ', np.mean(inputs.numpy()))
print('max = ', np.max(inputs.numpy()))
# Out:
# Batch of training data
# min =  0.0
# median =  0.07058824
# mean =  0.13989154
# max =  0.9843137
# Batch of validation data
# min =  0.0
# median =  0.19215687
# mean =  0.23965494
# max =  0.9843137
# Batch of test data
# min =  0.0
# median =  0.07450981
# mean =  0.14021312
# max =  1.0

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)
        epochs.append(epoch)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                   
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
                
            if phase == 'train':
                LOSS_train.append(epoch_loss)
                ACC_train.append(epoch_acc)
            if phase == 'val':
                LOSS_val.append(epoch_loss)
                ACC_val.append(epoch_acc)
        
        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model = resnet50(pretrained=False)
num_ftrs = model.fc.in_features

model.fc = nn.Linear(num_ftrs, 3)

model = model.to(device) #send the model to GPU if it is available or CPU otherwise

criterion = nn.CrossEntropyLoss()

optimizer_ft_randstart = optim.SGD(model.parameters(), lr=0.00005, momentum=0.9)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft_randstart, step_size=100, gamma=0.5)

# %%
model = models.resnet18(pretrained=False)
num_ftrs = model.fc.in_features

model.fc = nn.Linear(num_ftrs, 3)

model = model.to(device) 

criterion = nn.CrossEntropyLoss()


optimizer_ft_randstart = optim.SGD(model.parameters(), lr=0.00005, momentum=0.9)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft_randstart, step_size=100, gamma=0.5)

# %%
# print(model) # show CNN architecture

summary(model, (3, 170, 170)) # summarize the model
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 85, 85]           9,408
#        BatchNorm2d-2           [-1, 64, 85, 85]             128
#               ReLU-3           [-1, 64, 85, 85]               0
#          MaxPool2d-4           [-1, 64, 43, 43]               0
#             Conv2d-5           [-1, 64, 43, 43]          36,864
#        BatchNorm2d-6           [-1, 64, 43, 43]             128
#               ReLU-7           [-1, 64, 43, 43]               0
#             Conv2d-8           [-1, 64, 43, 43]          36,864
#        BatchNorm2d-9           [-1, 64, 43, 43]             128
#              ReLU-10           [-1, 64, 43, 43]               0
#        BasicBlock-11           [-1, 64, 43, 43]               0
#            Conv2d-12           [-1, 64, 43, 43]          36,864
#       BatchNorm2d-13           [-1, 64, 43, 43]             128
#              ReLU-14           [-1, 64, 43, 43]               0
#            Conv2d-15           [-1, 64, 43, 43]          36,864
#       BatchNorm2d-16           [-1, 64, 43, 43]             128
#              ReLU-17           [-1, 64, 43, 43]               0
#        BasicBlock-18           [-1, 64, 43, 43]               0
#            Conv2d-19          [-1, 128, 22, 22]          73,728
#       BatchNorm2d-20          [-1, 128, 22, 22]             256
#              ReLU-21          [-1, 128, 22, 22]               0
#            Conv2d-22          [-1, 128, 22, 22]         147,456
#       BatchNorm2d-23          [-1, 128, 22, 22]             256
#            Conv2d-24          [-1, 128, 22, 22]           8,192
#       BatchNorm2d-25          [-1, 128, 22, 22]             256
#              ReLU-26          [-1, 128, 22, 22]               0
#        BasicBlock-27          [-1, 128, 22, 22]               0
#            Conv2d-28          [-1, 128, 22, 22]         147,456
#       BatchNorm2d-29          [-1, 128, 22, 22]             256
#              ReLU-30          [-1, 128, 22, 22]               0
#            Conv2d-31          [-1, 128, 22, 22]         147,456
#       BatchNorm2d-32          [-1, 128, 22, 22]             256
#              ReLU-33          [-1, 128, 22, 22]               0
#        BasicBlock-34          [-1, 128, 22, 22]               0
#            Conv2d-35          [-1, 256, 11, 11]         294,912
#       BatchNorm2d-36          [-1, 256, 11, 11]             512
#              ReLU-37          [-1, 256, 11, 11]               0
#            Conv2d-38          [-1, 256, 11, 11]         589,824
#       BatchNorm2d-39          [-1, 256, 11, 11]             512
#            Conv2d-40          [-1, 256, 11, 11]          32,768
#       BatchNorm2d-41          [-1, 256, 11, 11]             512
#              ReLU-42          [-1, 256, 11, 11]               0
#        BasicBlock-43          [-1, 256, 11, 11]               0
#            Conv2d-44          [-1, 256, 11, 11]         589,824
#       BatchNorm2d-45          [-1, 256, 11, 11]             512
#              ReLU-46          [-1, 256, 11, 11]               0
#            Conv2d-47          [-1, 256, 11, 11]         589,824
#       BatchNorm2d-48          [-1, 256, 11, 11]             512
#              ReLU-49          [-1, 256, 11, 11]               0
#        BasicBlock-50          [-1, 256, 11, 11]               0
#            Conv2d-51            [-1, 512, 6, 6]       1,179,648
#       BatchNorm2d-52            [-1, 512, 6, 6]           1,024
#              ReLU-53            [-1, 512, 6, 6]               0
#            Conv2d-54            [-1, 512, 6, 6]       2,359,296
#       BatchNorm2d-55            [-1, 512, 6, 6]           1,024
#            Conv2d-56            [-1, 512, 6, 6]         131,072
#       BatchNorm2d-57            [-1, 512, 6, 6]           1,024
#              ReLU-58            [-1, 512, 6, 6]               0
#        BasicBlock-59            [-1, 512, 6, 6]               0
#            Conv2d-60            [-1, 512, 6, 6]       2,359,296
#       BatchNorm2d-61            [-1, 512, 6, 6]           1,024
#              ReLU-62            [-1, 512, 6, 6]               0
#            Conv2d-63            [-1, 512, 6, 6]       2,359,296
#       BatchNorm2d-64            [-1, 512, 6, 6]           1,024
#              ReLU-65            [-1, 512, 6, 6]               0
#        BasicBlock-66            [-1, 512, 6, 6]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                    [-1, 3]           1,539
# ================================================================
# Total params: 11,178,051
# Trainable params: 11,178,051
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.33
# Forward/backward pass size (MB): 37.72
# Params size (MB): 42.64
# Estimated Total Size (MB): 80.70
# ----------------------------------------------------------------

# %%
LOSS_train = []
LOSS_val = []
ACC_train = []
ACC_val = []
epochs = []

model = train_model(model, criterion, optimizer_ft_randstart, exp_lr_scheduler,
                        num_epochs=100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 1.0726 Acc: 0.4530
# val Loss: 0.9893 Acc: 0.4542
#
# Epoch 1/99
# ----------
# train Loss: 0.8436 Acc: 0.6251
# val Loss: 0.6332 Acc: 0.7761
#
# Epoch 2/99
# ----------
# train Loss: 0.7730 Acc: 0.6783
# val Loss: 0.6312 Acc: 0.7633
#
# Epoch 3/99
# ----------
# train Loss: 0.7344 Acc: 0.6915
# val Loss: 0.5694 Acc: 0.7548
#
# Epoch 4/99
# ----------
# train Loss: 0.6999 Acc: 0.7272
# val Loss: 0.5366 Acc: 0.7527
#
# Epoch 5/99
# ----------
# train Loss: 0.6755 Acc: 0.7454
# val Loss: 0.5183 Acc: 0.7527
#
# Epoch 6/99
# ----------
# train Loss: 0.6420 Acc: 0.7637
# val Loss: 0.5220 Acc: 0.7569
#
# Epoch 7/99
# ----------
# train Loss: 0.6157 Acc: 0.7768
# val Loss: 0.4972 Acc: 0.7783
#
# Epoch 8/99
# ----------
# train Loss: 0.5882 Acc: 0.7899
# val Loss: 0.5086 Acc: 0.7740
#
# Epoch 9/99
# ----------
# train Loss: 0.5701 Acc: 0.7987
# val Loss: 0.4794 Acc: 0.7676
#
# Epoch 10/99
# ----------
# train Loss: 0.5561 Acc: 0.8009
# val Loss: 0.4871 Acc: 0.7783
#
# Epoch 11/99
# ----------
# train Loss: 0.5221 Acc: 0.8140
# val Loss: 0.4893 Acc: 0.7825
#
# Epoch 12/99
# ----------
# train Loss: 0.5192 Acc: 0.8089
# val Loss: 0.4736 Acc: 0.7591
#
# Epoch 13/99
# ----------
# train Loss: 0.4849 Acc: 0.8271
# val Loss: 0.4769 Acc: 0.8017
#
# Epoch 14/99
# ----------
# train Loss: 0.4639 Acc: 0.8373
# val Loss: 0.4785 Acc: 0.7655
#
# Epoch 15/99
# ----------
# train Loss: 0.4503 Acc: 0.8403
# val Loss: 0.4818 Acc: 0.7932
#
# Epoch 16/99
# ----------
# train Loss: 0.4433 Acc: 0.8417
# val Loss: 0.4627 Acc: 0.7846
#
# Epoch 17/99
# ----------
# train Loss: 0.4182 Acc: 0.8570
# val Loss: 0.4765 Acc: 0.7484
#
# Epoch 18/99
# ----------
# train Loss: 0.4078 Acc: 0.8541
# val Loss: 0.4885 Acc: 0.7719
#
# Epoch 19/99
# ----------
# train Loss: 0.3904 Acc: 0.8607
# val Loss: 0.4757 Acc: 0.7676
#
# Epoch 20/99
# ----------
# train Loss: 0.3736 Acc: 0.8731
# val Loss: 0.4918 Acc: 0.7868
#
# Epoch 21/99
# ----------
# train Loss: 0.3597 Acc: 0.8826
# val Loss: 0.4815 Acc: 0.8017
#
# Epoch 22/99
# ----------
# train Loss: 0.3474 Acc: 0.8826
# val Loss: 0.4754 Acc: 0.7612
#
# Epoch 23/99
# ----------
# train Loss: 0.3427 Acc: 0.8899
# val Loss: 0.4763 Acc: 0.7569
#
# Epoch 24/99
# ----------
# train Loss: 0.3335 Acc: 0.8869
# val Loss: 0.4964 Acc: 0.7463
#
# Epoch 25/99
# ----------
# train Loss: 0.3230 Acc: 0.8899
# val Loss: 0.4718 Acc: 0.7633
#
# Epoch 26/99
# ----------
# train Loss: 0.3047 Acc: 0.9015
# val Loss: 0.4995 Acc: 0.7932
#
# Epoch 27/99
# ----------
# train Loss: 0.3069 Acc: 0.9037
# val Loss: 0.5828 Acc: 0.8060
#
# Epoch 28/99
# ----------
# train Loss: 0.2900 Acc: 0.9125
# val Loss: 0.4866 Acc: 0.7591
#
# Epoch 29/99
# ----------
# train Loss: 0.2727 Acc: 0.9241
# val Loss: 0.5173 Acc: 0.7591
#
# Epoch 30/99
# ----------
# train Loss: 0.2771 Acc: 0.9227
# val Loss: 0.4972 Acc: 0.7548
#
# Epoch 31/99
# ----------
# train Loss: 0.2584 Acc: 0.9307
# val Loss: 0.5226 Acc: 0.7697
#
# Epoch 32/99
# ----------
# train Loss: 0.2549 Acc: 0.9271
# val Loss: 0.4867 Acc: 0.7676
#
# Epoch 33/99
# ----------
# train Loss: 0.2525 Acc: 0.9322
# val Loss: 0.5161 Acc: 0.7740
#
# Epoch 34/99
# ----------
# train Loss: 0.2448 Acc: 0.9292
# val Loss: 0.4916 Acc: 0.7697
#
# Epoch 35/99
# ----------
# train Loss: 0.2255 Acc: 0.9504
# val Loss: 0.6040 Acc: 0.7974
#
# Epoch 36/99
# ----------
# train Loss: 0.2285 Acc: 0.9380
# val Loss: 0.5409 Acc: 0.7719
#
# Epoch 37/99
# ----------
# train Loss: 0.2253 Acc: 0.9446
# val Loss: 0.4554 Acc: 0.7548
#
# Epoch 38/99
# ----------
# train Loss: 0.2028 Acc: 0.9555
# val Loss: 0.4979 Acc: 0.7633
#
# Epoch 39/99
# ----------
# train Loss: 0.1999 Acc: 0.9584
# val Loss: 0.5096 Acc: 0.7612
#
# Epoch 40/99
# ----------
# train Loss: 0.1977 Acc: 0.9526
# val Loss: 0.4843 Acc: 0.7612
#
# Epoch 41/99
# ----------
# train Loss: 0.1884 Acc: 0.9686
# val Loss: 0.5111 Acc: 0.7633
#
# Epoch 42/99
# ----------
# train Loss: 0.1902 Acc: 0.9606
# val Loss: 0.5107 Acc: 0.7505
#
# Epoch 43/99
# ----------
# train Loss: 0.1705 Acc: 0.9716
# val Loss: 0.5197 Acc: 0.7697
#
# Epoch 44/99
# ----------
# train Loss: 0.1657 Acc: 0.9679
# val Loss: 0.5003 Acc: 0.7612
#
# Epoch 45/99
# ----------
# train Loss: 0.1604 Acc: 0.9745
# val Loss: 0.4783 Acc: 0.7484
#
# Epoch 46/99
# ----------
# train Loss: 0.1655 Acc: 0.9672
# val Loss: 0.5036 Acc: 0.7505
#
# Epoch 47/99
# ----------
# train Loss: 0.1569 Acc: 0.9737
# val Loss: 0.5494 Acc: 0.7463
#
# Epoch 48/99
# ----------
# train Loss: 0.1500 Acc: 0.9730
# val Loss: 0.5343 Acc: 0.7399
#
# Epoch 49/99
# ----------
# train Loss: 0.1392 Acc: 0.9788
# val Loss: 0.4526 Acc: 0.7655
#
# Epoch 50/99
# ----------
# train Loss: 0.1328 Acc: 0.9803
# val Loss: 0.5463 Acc: 0.7569
#
# Epoch 51/99
# ----------
# train Loss: 0.1360 Acc: 0.9752
# val Loss: 0.4587 Acc: 0.7484
#
# Epoch 52/99
# ----------
# train Loss: 0.1310 Acc: 0.9803
# val Loss: 0.5404 Acc: 0.7463
#
# Epoch 53/99
# ----------
# train Loss: 0.1262 Acc: 0.9825
# val Loss: 0.6314 Acc: 0.7846
#
# Epoch 54/99
# ----------
# train Loss: 0.1166 Acc: 0.9854
# val Loss: 0.5379 Acc: 0.7612
#
# Epoch 55/99
# ----------
# train Loss: 0.1234 Acc: 0.9796
# val Loss: 0.5753 Acc: 0.7505
#
# Epoch 56/99
# ----------
# train Loss: 0.1229 Acc: 0.9803
# val Loss: 0.4914 Acc: 0.7569
#
# Epoch 57/99
# ----------
# train Loss: 0.1164 Acc: 0.9832
# val Loss: 0.4460 Acc: 0.7804
#
# Epoch 58/99
# ----------
# train Loss: 0.1120 Acc: 0.9825
# val Loss: 0.5416 Acc: 0.7484
#
# Epoch 59/99
# ----------
# train Loss: 0.0963 Acc: 0.9898
# val Loss: 0.6105 Acc: 0.7783
#
# Epoch 60/99
# ----------
# train Loss: 0.1028 Acc: 0.9854
# val Loss: 0.5298 Acc: 0.7655
#
# Epoch 61/99
# ----------
# train Loss: 0.0989 Acc: 0.9876
# val Loss: 0.4702 Acc: 0.7761
#
# Epoch 62/99
# ----------
# train Loss: 0.1031 Acc: 0.9869
# val Loss: 0.5579 Acc: 0.7569
#
# Epoch 63/99
# ----------
# train Loss: 0.0889 Acc: 0.9898
# val Loss: 0.6082 Acc: 0.7783
#
# Epoch 64/99
# ----------
# train Loss: 0.0840 Acc: 0.9920
# val Loss: 0.5470 Acc: 0.7463
#
# Epoch 65/99
# ----------
# train Loss: 0.0814 Acc: 0.9891
# val Loss: 0.5129 Acc: 0.7697
#
# Epoch 66/99
# ----------
# train Loss: 0.0814 Acc: 0.9898
# val Loss: 0.5118 Acc: 0.7569
#
# Epoch 67/99
# ----------
# train Loss: 0.0773 Acc: 0.9934
# val Loss: 0.5453 Acc: 0.7740
#
# Epoch 68/99
# ----------
# train Loss: 0.0764 Acc: 0.9912
# val Loss: 0.4385 Acc: 0.7612
#
# Epoch 69/99
# ----------
# train Loss: 0.0770 Acc: 0.9920
# val Loss: 0.5125 Acc: 0.7463
#
# Epoch 70/99
# ----------
# train Loss: 0.0730 Acc: 0.9934
# val Loss: 0.5362 Acc: 0.7569
#
# Epoch 71/99
# ----------
# train Loss: 0.0631 Acc: 0.9956
# val Loss: 0.4955 Acc: 0.7783
#
# Epoch 72/99
# ----------
# train Loss: 0.0611 Acc: 0.9927
# val Loss: 0.4570 Acc: 0.7463
#
# Epoch 73/99
# ----------
# train Loss: 0.0736 Acc: 0.9927
# val Loss: 0.5520 Acc: 0.7548
#
# Epoch 74/99
# ----------
# train Loss: 0.0618 Acc: 0.9927
# val Loss: 0.7123 Acc: 0.7505
#
# Epoch 75/99
# ----------
# train Loss: 0.0605 Acc: 0.9949
# val Loss: 0.4817 Acc: 0.7377
#
# Epoch 76/99
# ----------
# train Loss: 0.0605 Acc: 0.9927
# val Loss: 0.4739 Acc: 0.7633
#
# Epoch 77/99
# ----------
# train Loss: 0.0583 Acc: 0.9949
# val Loss: 0.4531 Acc: 0.7697
#
# Epoch 78/99
# ----------
# train Loss: 0.0595 Acc: 0.9927
# val Loss: 0.5187 Acc: 0.7846
#
# Epoch 79/99
# ----------
# train Loss: 0.0580 Acc: 0.9912
# val Loss: 0.5554 Acc: 0.7527
#
# Epoch 80/99
# ----------
# train Loss: 0.0599 Acc: 0.9934
# val Loss: 0.5569 Acc: 0.7505
#
# Epoch 81/99
# ----------
# train Loss: 0.0505 Acc: 0.9949
# val Loss: 0.4677 Acc: 0.7804
#
# Epoch 82/99
# ----------
# train Loss: 0.0505 Acc: 0.9934
# val Loss: 0.5291 Acc: 0.7719
#
# Epoch 83/99
# ----------
# train Loss: 0.0498 Acc: 0.9942
# val Loss: 0.4649 Acc: 0.7505
#
# Epoch 84/99
# ----------
# train Loss: 0.0464 Acc: 0.9964
# val Loss: 0.5243 Acc: 0.7548
#
# Epoch 85/99
# ----------
# train Loss: 0.0511 Acc: 0.9920
# val Loss: 0.6798 Acc: 0.7676
#
# Epoch 86/99
# ----------
# train Loss: 0.0542 Acc: 0.9956
# val Loss: 1.1479 Acc: 0.6461
#
# Epoch 87/99
# ----------
# train Loss: 0.0515 Acc: 0.9949
# val Loss: 0.5424 Acc: 0.7569
#
# Epoch 88/99
# ----------
# train Loss: 0.0419 Acc: 0.9956
# val Loss: 0.5432 Acc: 0.7740
#
# Epoch 89/99
# ----------
# train Loss: 0.0409 Acc: 0.9964
# val Loss: 0.5081 Acc: 0.7591
#
# Epoch 90/99
# ----------
# train Loss: 0.0429 Acc: 0.9956
# val Loss: 0.5246 Acc: 0.7804
#
# Epoch 91/99
# ----------
# train Loss: 0.0387 Acc: 0.9956
# val Loss: 0.5056 Acc: 0.7846
#
# Epoch 92/99
# ----------
# train Loss: 0.0350 Acc: 0.9978
# val Loss: 0.6257 Acc: 0.7527
#
# Epoch 93/99
# ----------
# train Loss: 0.0348 Acc: 0.9956
# val Loss: 0.5111 Acc: 0.7761
#
# Epoch 94/99
# ----------
# train Loss: 0.0373 Acc: 0.9956
# val Loss: 0.4513 Acc: 0.7761
#
# Epoch 95/99
# ----------
# train Loss: 0.0508 Acc: 0.9927
# val Loss: 0.5494 Acc: 0.7761
#
# Epoch 96/99
# ----------
# train Loss: 0.0354 Acc: 0.9971
# val Loss: 0.5074 Acc: 0.7420
#
# Epoch 97/99
# ----------
# train Loss: 0.0378 Acc: 0.9942
# val Loss: 0.4793 Acc: 0.7697
#
# Epoch 98/99
# ----------
# train Loss: 0.0335 Acc: 0.9964
# val Loss: 0.7516 Acc: 0.7740
#
# Epoch 99/99
# ----------
# train Loss: 0.0358 Acc: 0.9956
# val Loss: 0.5126 Acc: 0.7676
#
# Training complete in 20m 57s
# Best val Acc: 0.805970

# %%
LOSS_train
LOSS_val 

plt.plot(epochs,LOSS_train,)
plt.plot(epochs,LOSS_val,)
plt.legend(["Loss_Treino","Loss_Validação"])
plt.xlabel('Épocas  ')
plt.ylabel('Loss ')
plt.show()

# %%
def predic_model(model, plot_img = False, num_images=24):
    was_training = model.training
    model.eval()
    images_so_far = 0
    PREDICTED = []
    LABEL = []

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['test']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
              images_so_far += 1
              PREDICTED.append(class_names[preds[j]])
              LABEL.append(class_names[labels[j]])
              if plot_img:
                plt.figure()
                plt.imshow(inputs.cpu().data[j].numpy().transpose((1, 2, 0)))
                plt.axis('off')
                plt.title('predicted: {} - label: {}'.format(class_names[preds[j]], class_names[labels[j]]))
                plt.plot()

              if images_so_far == num_images:
                model.train(mode=was_training)
                # break
                return PREDICTED, LABEL

        model.train(mode=was_training)

    return PREDICTED, LABEL

# %%
test_group_len = 26
PREDICTED, LABEL = predic_model(model, plot_img = False, num_images=test_group_len)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c6e8d79b5c84> in <cell line: 2>()
#       1 test_group_len = 26
# ----> 2 PREDICTED, LABEL = predic_model(model, plot_img = False, num_images=test_group_len)
#
# NameError: name 'predic_model' is not defined
